# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
import plotly.graph_objects as go

# %matplotlib inline

data = pd.read_csv(r'C:/Users/Dell/Desktop/Apollo563.csv')

def mean_std(x):
    w = (str(round(pd.DataFrame(x).mean(),1)[0]))
    e = (str(round(pd.DataFrame(x).std(),1)[0]))
    t = w + "(" + e +")"
    return t

def inout_count(x):
    a = []
    b = []
    for i in x:
        
        if i == 'Out Born':
            b.append(x)
        else:
            a.append(x)

    inborn = str(len(a))
    outborn = str(len(b))
    return (inborn,outborn)

def median_IQR(x):
    q1 = str(pd.DataFrame(x).quantile(.25)[0])
    q2 = str(pd.DataFrame(x).quantile(.75)[0])
    q3 = str(pd.DataFrame(x).median()[0])
    q4 = q3 + "(" +q1 +"-" + q2 + ")"
    
    
    
    return q4

def gender_count(x):
    a = []
    b = []
    for i in x:
        
        if i == 'Male':
            a.append(x)
        else:
            b.append(x)

    male = str(len(a))
    female = str(len(b))
    return (male,female)

def MOD_count(x):
    a = []
    b = []
    for i in x:
        
        if i == 'LSCS':
            b.append(x)
        else:
            a.append(x)

    nvd = str(len(a))
    lscs = str(len(b))
    return (nvd,lscs)


def single_count1(x):
    
    a = []
    b = []
    for i in x:
             
        if i == 'Multiple':
            a.append(x)
        else:
            b.append(x)

    multiple = str(len(a))
    single = str(len(b))
    return (single,multiple)

def neofax_count(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == 'No_err':
            a.append(x)
        elif i == 'ERROR':
            b.append(x)
        else:
            c.append(x)

    no_error = str(len(a))
    error = str(len(b))
    NE = str(len(c))
    
    return (no_error,error,NE)

def medadmin_count(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == 'No_err':
            a.append(x)
        elif i == 'ERROR':
            b.append(x)
        else:
            c.append(x)

    no_error = str(len(a))
    error = str(len(b))
    NE = str(len(c))
    return (no_error,error,NE)

def espgan_count(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == 'No_err':
            a.append(x)
        elif i == 'ERROR':
            b.append(x)
        else:
            c.append(x)

    no_error = str(len(a))
    error = str(len(b))
    NE = str(len(c))
    return (no_error,error,NE)

def nutri_count(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == 'No_err':
            a.append(x)
        elif i == 'ERROR':
            b.append(x)
        else:
            c.append(x)

    no_error = str(len(a))
    error = str(len(b))
    NE = str(len(c))
    return (no_error,error,NE)

def RDS_count(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == True:
            a.append(x)
        else:
            b.append(x)
        

    t = str(len(a))
    f = str(len(b))
    return (t,f)

def jaundice_count(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == True:
            a.append(x)
        else:
            b.append(x)
        

    t = str(len(a))
    f = str(len(b))
    return (t,f)

def spesis_count(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == True:
            a.append(x)
        else:
            b.append(x)
        

    t = str(len(a))
    f = str(len(b))
    return (t,f)

def spesis_count1(x):
    a = []
    b = []
    c=[]
    for i in x:
        
        if i == 'true':
            a.append(x)
        else:
            b.append(x)
        

    t = str(len(a))
    f = str(len(b))
    return (t,f)

#def plot_table(x):
x_R = data



headerColor = 'grey'
rowEvenColor = 'lightgrey'
rowOddColor = 'white'

fig = go.Figure(data=[go.Table(
  header=dict(
    values=['<b>FIELDS</b>','<b>BASELINE</b>'],
    line_color='darkslategray',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=12)
  ),
  cells=dict(
    values=[
      ['Count','Gestation','Birth Weight','LOS (Median IQR)','Admission Weight', 'Male','Female', 'One Min APGAR', 'Five Min APGAR', 'NVD','LSCS','Neo Fax No Error','NeoFax Error','NeoFaxNot Eligible','Nutri Admin No Error','Nutri Admin Error','Nutri Admin Not Eligible','ESPGHAN No Error','ESPDHAN Error','ESPGHAN Not Eligible','Med Admin No Error','Med Admin Error','Med Admin Not Eligible','In Born','Out Born','Jaundice True','Jaundice False','Sepsis True','Sepsis False','RDS True','RDS False','Single','Multiple','Antenatal Steroids True','Antenatal Steroids False'],
      [x_R.count()[0],mean_std(x_R['Gestation']),mean_std(x_R['birthweight']),median_IQR(x_R['LOS']),mean_std(x_R['admissionweight']), gender_count(x_R['Gender'])[0],gender_count(x_R['Gender'])[1], mean_std(x_R['ONEMIN_APGAR']), mean_std(x_R['FIVEMIN_APGAR']), MOD_count(x_R['MODE_OF_DELIVERY'])[0],MOD_count(x_R['MODE_OF_DELIVERY'])[1], neofax_count(x_R['NEOFAX_ERRORS'])[0],neofax_count(x_R['NEOFAX_ERRORS'])[1],neofax_count(x_R['NEOFAX_ERRORS'])[2],nutri_count(x_R['NUTR_ADMIN'])[0],nutri_count(x_R['NUTR_ADMIN'])[1],nutri_count(x_R['NUTR_ADMIN'])[2], espgan_count(x_R['ESPGHAN'])[0],espgan_count(x_R['ESPGHAN'])[1],espgan_count(x_R['ESPGHAN'])[2],neofax_count(x_R['MED_ADMIN_ERRORS'])[0],neofax_count(x_R['MED_ADMIN_ERRORS'])[1],neofax_count(x_R['MED_ADMIN_ERRORS'])[2],inout_count(x_R['inout_patient_status'])[0],inout_count(x_R['inout_patient_status'])[1],jaundice_count(x_R['JAUNDICE'])[0],jaundice_count(x_R['JAUNDICE'])[1],spesis_count(x_R['SEPSIS'])[0],spesis_count(x_R['SEPSIS'])[1], RDS_count(x_R['RDS'])[0],RDS_count(x_R['RDS'])[1],single_count1(x_R['baby_type'])[0],single_count1(x_R['baby_type'])[1],spesis_count(x_R['ANTENATA_STEROIDS'])[0],spesis_count(x_R['ANTENATA_STEROIDS'])[1]],



      ],
    line_color='darkslategray',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor]*18],
    align = ['left', 'center'],
    font = dict(color = 'darkslategray', size = 11)
    ))
])

fig.show()

x_R = data[data['Gestation']<34]
x_2 = data[data['Gestation']>37]
x_1 = data[(data['Gestation']>=34) & (data['Gestation']<=37)]

headerColor = 'grey'
rowEvenColor = 'lightgrey'
rowOddColor = 'white'

fig = go.Figure(data=[go.Table(
  header=dict(
    values=['<b>FIELDS</b>','<b>Less Than 34</b>','<b>34 to 37</b>','<b>Greater than 37</b>'],
    line_color='darkslategray',
    fill_color=headerColor,
    align=['left','center'],
    font=dict(color='white', size=12)
  ),
  cells=dict(
    values=[
      ['Count','Gestation','Birth Weight','LOS (Median IQR)','Admission Weight', 'Male','Female', 'One Min APGAR', 'Five Min APGAR', 'NVD','LSCS','Neo Fax No Error','NeoFax Error','NeoFaxNot Eligible','Nutri Admin No Error','Nutri Admin Error','Nutri Admin Not Eligible','ESPGHAN No Error','ESPDHAN Error','ESPGHAN Not Eligible','Med Admin No Error','Med Admin Error','Med Admin Not Eligible','In Born','Out Born','Jaundice True','Jaundice False','Sepsis True','Sepsis False','RDS True','RDS False','Single','Multiple','Antenatal Steroids True','Antenatal Steroids False'],
      [x_R.count()[0],mean_std(x_R['Gestation']),mean_std(x_R['birthweight']),median_IQR(x_R['LOS']),mean_std(x_R['admissionweight']), gender_count(x_R['Gender'])[0],gender_count(x_R['Gender'])[1], mean_std(x_R['ONEMIN_APGAR']), mean_std(x_R['FIVEMIN_APGAR']), MOD_count(x_R['MODE_OF_DELIVERY'])[0],MOD_count(x_R['MODE_OF_DELIVERY'])[1], neofax_count(x_R['NEOFAX_ERRORS'])[0],neofax_count(x_R['NEOFAX_ERRORS'])[1],neofax_count(x_R['NEOFAX_ERRORS'])[2],nutri_count(x_R['NUTR_ADMIN'])[0],nutri_count(x_R['NUTR_ADMIN'])[1],nutri_count(x_R['NUTR_ADMIN'])[2], espgan_count(x_R['ESPGHAN'])[0],espgan_count(x_R['ESPGHAN'])[1],espgan_count(x_R['ESPGHAN'])[2],neofax_count(x_R['MED_ADMIN_ERRORS'])[0],neofax_count(x_R['MED_ADMIN_ERRORS'])[1],neofax_count(x_R['MED_ADMIN_ERRORS'])[2],inout_count(x_R['inout_patient_status'])[0],inout_count(x_R['inout_patient_status'])[1],jaundice_count(x_R['JAUNDICE'])[0],jaundice_count(x_R['JAUNDICE'])[1],spesis_count(x_R['SEPSIS'])[0],spesis_count(x_R['SEPSIS'])[1], RDS_count(x_R['RDS'])[0],RDS_count(x_R['RDS'])[1],single_count1(x_R['baby_type'])[0],single_count1(x_R['baby_type'])[1],spesis_count(x_R['ANTENATA_STEROIDS'])[0],spesis_count(x_R['ANTENATA_STEROIDS'])[1]],
      [x_1.count()[1],mean_std(x_1['Gestation']),mean_std(x_1['birthweight']),median_IQR(x_1['LOS']),mean_std(x_1['admissionweight']), gender_count(x_1['Gender'])[0],gender_count(x_1['Gender'])[1], mean_std(x_1['ONEMIN_APGAR']), mean_std(x_1['FIVEMIN_APGAR']), MOD_count(x_1['MODE_OF_DELIVERY'])[0],MOD_count(x_1['MODE_OF_DELIVERY'])[1], neofax_count(x_1['NEOFAX_ERRORS'])[0],neofax_count(x_1['NEOFAX_ERRORS'])[1],neofax_count(x_1['NEOFAX_ERRORS'])[2],nutri_count(x_1['NUTR_ADMIN'])[0],nutri_count(x_1['NUTR_ADMIN'])[1],nutri_count(x_1['NUTR_ADMIN'])[2], espgan_count(x_1['ESPGHAN'])[0],espgan_count(x_1['ESPGHAN'])[1],espgan_count(x_1['ESPGHAN'])[2],neofax_count(x_1['MED_ADMIN_ERRORS'])[0],neofax_count(x_1['MED_ADMIN_ERRORS'])[1],neofax_count(x_1['MED_ADMIN_ERRORS'])[2],inout_count(x_1['inout_patient_status'])[0],inout_count(x_1['inout_patient_status'])[1],jaundice_count(x_1['JAUNDICE'])[0],jaundice_count(x_1['JAUNDICE'])[1],spesis_count(x_1['SEPSIS'])[0],spesis_count(x_1['SEPSIS'])[1], RDS_count(x_1['RDS'])[0],RDS_count(x_1['RDS'])[1],single_count1(x_1['baby_type'])[0],single_count1(x_1['baby_type'])[1],spesis_count(x_1['ANTENATA_STEROIDS'])[0],spesis_count(x_1['ANTENATA_STEROIDS'])[1]],
      [x_2.count()[2],mean_std(x_2['Gestation']),mean_std(x_2['birthweight']),median_IQR(x_2['LOS']),mean_std(x_2['admissionweight']), gender_count(x_2['Gender'])[0],gender_count(x_2['Gender'])[1], mean_std(x_2['ONEMIN_APGAR']), mean_std(x_2['FIVEMIN_APGAR']), MOD_count(x_2['MODE_OF_DELIVERY'])[0],MOD_count(x_2['MODE_OF_DELIVERY'])[1], neofax_count(x_2['NEOFAX_ERRORS'])[0],neofax_count(x_2['NEOFAX_ERRORS'])[1],neofax_count(x_2['NEOFAX_ERRORS'])[2],nutri_count(x_2['NUTR_ADMIN'])[0],nutri_count(x_2['NUTR_ADMIN'])[1],nutri_count(x_2['NUTR_ADMIN'])[2], espgan_count(x_2['ESPGHAN'])[0],espgan_count(x_2['ESPGHAN'])[1],espgan_count(x_2['ESPGHAN'])[2],neofax_count(x_2['MED_ADMIN_ERRORS'])[0],neofax_count(x_2['MED_ADMIN_ERRORS'])[1],neofax_count(x_2['MED_ADMIN_ERRORS'])[2],inout_count(x_2['inout_patient_status'])[0],inout_count(x_2['inout_patient_status'])[1],jaundice_count(x_2['JAUNDICE'])[0],jaundice_count(x_2['JAUNDICE'])[1],spesis_count(x_2['SEPSIS'])[0],spesis_count(x_2['SEPSIS'])[1], RDS_count(x_2['RDS'])[0],RDS_count(x_2['RDS'])[1],single_count1(x_2['baby_type'])[0],single_count1(x_2['baby_type'])[1],spesis_count(x_2['ANTENATA_STEROIDS'])[0],spesis_count(x_2['ANTENATA_STEROIDS'])[1]],


      ],
    line_color='darkslategray',
    # 2-D list of colors for alternating rows
    fill_color = [[rowOddColor,rowEvenColor]*18],
    align = ['left', 'center'],
    font = dict(color = 'darkslategray', size = 11)
    ))
])

fig.show()
